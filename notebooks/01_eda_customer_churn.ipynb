# %% [markdown]
# # Customer Churn - Analisi Esplorativa
#
# Questo notebook contiene una **analisi esplorativa (EDA)** del dataset di customer churn.
#
# Step principali:
# - Caricamento dei dati grezzi o sintetici
# - Analisi univariata e bivariata delle feature principali
# - Analisi della distribuzione del target `churn`
# - Insight di business su quali variabili influenzano maggiormente l'abbandono

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

base_dir = os.path.dirname(os.path.dirname(os.getcwd())) if os.getcwd().endswith('notebooks') else os.getcwd()
raw_path = os.path.join(base_dir, 'data', 'raw', 'customer_churn_synthetic.csv')
df = pd.read_csv(raw_path)
df.head()
